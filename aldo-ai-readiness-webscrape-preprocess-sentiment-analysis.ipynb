# %% [markdown]
# # Aldo Group's AI Readiness based on the web

# %% [markdown]
# 1. **Web Scraping**:
#    - **Objective**: Gather the latest articles mentioning both "ALDO" and AI-related keywords.
#    - **Alternatives**:
#      - Utilize libraries like `requests` to fetch web pages and `BeautifulSoup` for parsing HTML content.
#      - ✅ Use APIs connectors like Google's Programmable Search Engine.
#
# 2. **Data Storage**:
#    - Store the extracted data in a CSV file and call it after: Web scraping, Preprocessing, and Sentiment Analysis
#
# 3. **Data Preprocessing**:
#    - **Objective**: Clean the article content for accurate sentiment analysis.
#    - **Steps**:
#      - Convert text to lowercase.
#      - Remove punctuation, numbers, and special characters.
#      - Eliminate stop words and names.
#      - Perform stemming or lemmatization to reduce words to their base forms.
#
# 4. **Sentiment Analysis**:
#    - **Objective**: Determine the sentiment of each article.
#    - **Tools**:
#      - Use libraries like `TextBlob` or `VADER` from the `nltk` library.
#    - **Process**:
#      - Analyze the preprocessed content to assign a sentiment score ranging from -1 (very negative) to 1 (very positive).
#      - Add a new column "Sentiment Score" to the CSV file to store the average of the two scores.

# %%
# Install
#!pip install requests beautifulsoup4 textblob nltk

# Imports
import requests
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime
import re

# %%
API_KEY = "replace with your key"
CX = "replace with your cx"   # Google search engine ID
QUERY = "Aldo Group AI" # Replace with your query

headers = {"user-agent": "replace with your user agent"} #Find your agent on: https://httpbin.org/user-agent

url = f"https://www.googleapis.com/customsearch/v1?key={API_KEY}&cx={CX}&q={QUERY}"

response = requests.get(url)
data = response.json()

# Get dates from search results
for item in data.get("items", []):
    print(item.get("title"), item.get("link"))


data
# Out:
# ALDO Group Invests in Predictive AI for Demand Forecasting - ASUG https://www.asug.com/insights/aldo-group-invests-in-predictive-ai-for-demand-forecasting
# ALDO Group Prioritizes Predictive AI Over Generative AI. Here's ... https://www.cxtoday.com/customer-data-platform/aldo-group-prioritizes-predictive-ai-over-generative-ai-heres-why/
# Inside ALDO's in-house generative AI and machine learning strategy ... https://digiday.com/marketing/inside-aldos-in-house-generative-ai-and-machine-learning-strategy/
# ALDO Group | Contentful https://www.contentful.com/case-studies/aldo-group/
# Aldo's AI Investments Include Celebrity Picks and Demand ... https://consumergoods.com/aldos-ai-investments-include-celebrity-picks-and-demand-forecasting
# How Aldo puts its best foot forward with a unified e-commerce ... https://emarsys.com/why-emarsys/success-stories/how-aldo-puts-its-best-foot-forward-with-a-unified-e-commerce-system/
# ALDO Group's AI Revolution | Fatih Nayebi, Ph.D. posted on the ... https://www.linkedin.com/posts/thefatih_2023-impact-report-aldo-group-activity-7217538329657929729-TaQW
# DataSphere Lab & ALDO Group Partnership: Shaping the Future of ... https://www.mcgill.ca/bensadoun-school/data-sphere-lab/our-stakeholders/datasphere-lab-aldo-group-partnership
# SCALE AI is announcing investments of more than $20 million in 5 ... https://www.scaleai.ca/scale-ai-is-announcing-investments-of-more-than-20-million-in-5-ai-projects-for-intelligent-supply-chains/
# Retail Gen AI Hackathon | Bensadoun School of Retail Management ... https://www.mcgill.ca/bensadoun-school/featured-events/retail-gen-ai-hackathon
# {'kind': 'customsearch#search',
#  'url': {'type': 'application/json',
#   'template': 'https://www.googleapis.com/customsearch/v1?q={searchTerms}&num={count?}&start={startIndex?}&lr={language?}&safe={safe?}&cx={cx?}&sort={sort?}&filter={filter?}&gl={gl?}&cr={cr?}&googlehost={googleHost?}&c2coff={disableCnTwTranslation?}&hq={hq?}&hl={hl?}&siteSearch={siteSearch?}&siteSearchFilter={siteSearchFilter?}&exactTerms={exactTerms?}&excludeTerms={excludeTerms?}&linkSite={linkSite?}&orTerms={orTerms?}&dateRestrict={dateRestrict?}&lowRange={lowRange?}&highRange={highRange?}&searchType={searchType}&fileType={fileType?}&rights={rights?}&imgSize={imgSize?}&imgType={imgType?}&imgColorType={imgColorType?}&imgDominantColor={imgDominantColor?}&alt=json'},
#  'queries': {'request': [{'title': 'Google Custom Search - Aldo Group AI',
#     'totalResults': '13800000',
#     'searchTerms': 'Aldo Group AI',
#     'count': 10,
#     'startIndex': 1,
#     'inputEncoding': 'utf8',
#     'outputEncoding': 'utf8',
#     'safe': 'off',
#     'cx': '2090b68ec361b436d'}],
#   'nextPage': [{'title': 'Google Custom Search - Aldo Group AI',
#     'totalResults': '13800000',
#     'searchTerms': 'Aldo Group AI',
#     'count': 10,
#     'startIndex': 11,
#     'inputEncoding': 'utf8',
#     'outputEncoding': 'utf8',
#     'safe': 'off',
#     'cx': '2090b68ec361b436d'}]},
#  'context': {'title': 'Aldo Group and AI'},
#  'searchInformation': {'searchTime': 0.213345,
#   'formattedSearchTime': '0.21',
#   'totalResults': '13800000',
#   'formattedTotalResults': '13,800,000'},
#  'items': [{'kind': 'customsearch#result',
#    'title': 'ALDO Group Invests in Predictive AI for Demand Forecasting - ASUG',
#    'htmlTitle': '<b>ALDO Group</b> Invests in Predictive <b>AI</b> for Demand Forecasting - ASUG',
#    'link': 'https://www.asug.com/insights/aldo-group-invests-in-predictive-ai-for-demand-forecasting',
#    'displayLink': 'www.asug.com',
#    'snippet': 'Aug 16, 2024 ... ALDO Group is helping to develop a generative AI model that will provide its shoppers with customized product recommendations based on particular celebrities\xa0...',
#    'htmlSnippet': 'Aug 16, 2024 <b>...</b> <b>ALDO Group</b> is helping to develop a generative <b>AI</b> model that will provide its shoppers with customized product recommendations based on particular celebrities&nbsp;...',
#    'formattedUrl': 'https://www.asug.com/.../aldo-group-invests-in-predictive-ai-for-demand-f...',
#    'htmlFormattedUrl': 'https://www.asug.com/.../<b>aldo</b>-<b>group</b>-invests-in-predictive-<b>ai</b>-for-demand-f...',
#    'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcR7wkU-vmck0n1aQCIt2hJHVFZ2wczw-tgAPKWwtbYnbIQbb9flpCXjWmc&s',
#       'width': '310',
#       'height': '163'}],
#     'metatags': [{'og:see_also': 'http://www.youtube.com/user/ASUGtv',
#       'og:image': 'https://s3.us-east-1.amazonaws.com/asugv5-assets/archive/uploads/images/main/_1200x630_crop_center-center_82_none/shutterstock_1326695171.jpg?mtime=1723647928',
#       'fb:profile_id': '100622776646794',
#       'og:type': 'website',
#       'og:image:width': '1200',
#       'og:image:alt': 'ASUG logo with orange background and white text',
#       'twitter:card': 'summary_large_image',
#       'twitter:title': 'ALDO Group Invests in Predictive AI for Demand Forecasting',
#       'og:site_name': 'ASUG',
#       'og:title': 'ALDO Group Invests in Predictive AI for Demand Forecasting',
#       'og:image:height': '630',
#       'twitter:image:height': '418',
#       'og:description': 'In a recent virtual event hosted by SAP, Matthieu Houle, Chief Information Officer at ALDO Group, detailed the company’s success in leveraging value-driven AI while harnessing SAP’s composable CX solutions to increase revenue and loyalty.',
#       'twitter:creator': '@asug365',
#       'twitter:image': 'https://s3.us-east-1.amazonaws.com/asugv5-assets/archive/uploads/images/main/_1200x630_crop_center-center_82_none/shutterstock_1326695171.jpg?mtime=1723647928',
#       'referrer': 'no-referrer-when-downgrade',
#       'twitter:image:alt': 'ASUG logo with orange background and white text',
#       'twitter:site': '@asug365',
#       'twitter:image:width': '800',
#       'viewport': 'width=device-width',
#       'twitter:description': 'In a recent virtual event hosted by SAP, Matthieu Houle, Chief Information Officer at ALDO Group, detailed the company’s success in leveraging value-driven AI while harnessing SAP’s composable CX solutions to increase revenue and loyalty.',
#       'og:locale': 'en_US',
#       'og:url': 'https://www.asug.com/insights/aldo-group-invests-in-predictive-ai-for-demand-forecasting'}],
#     'cse_image': [{'src': 'https://s3.us-east-1.amazonaws.com/asugv5-assets/archive/uploads/images/main/_1200x630_crop_center-center_82_none/shutterstock_1326695171.jpg?mtime=1723647928'}]}},
#   {'kind': 'customsearch#result',
#    'title': "ALDO Group Prioritizes Predictive AI Over Generative AI. Here's ...",
#    'htmlTitle': '<b>ALDO Group</b> Prioritizes Predictive <b>AI</b> Over Generative <b>AI</b>. Here&#39;s ...',
#    'link': 'https://www.cxtoday.com/customer-data-platform/aldo-group-prioritizes-predictive-ai-over-generative-ai-heres-why/',
#    'displayLink': 'www.cxtoday.com',
#    'snippet': "Aug 1, 2024 ... Matthieu Houle, CIO of ALDO Group, discusses his team's GenAI experiences, latest innovations, and the delicacies of change management.",
#    'htmlSnippet': 'Aug 1, 2024 <b>...</b> Matthieu Houle, CIO of <b>ALDO Group</b>, discusses his team&#39;s GenAI experiences, latest innovations, and the delicacies of change management.',
#    'formattedUrl': 'https://www.cxtoday.com/.../aldo-group-prioritizes-predictive-ai-over-gene...',
#    'htmlFormattedUrl': 'https://www.cxtoday.com/.../<b>aldo</b>-<b>group</b>-prioritizes-predictive-<b>ai</b>-over-gene...',
#    'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTZwaG2hwj3eoSZwyGw_Wq7hrKBnLN66SgpyWW1f7ifwzOqMU6iY6m-k2o&s',
#       'width': '318',
#       'height': '159'}],
#     'metatags': [{'og:image': 'https://www.cxtoday.com/wp-content/uploads/2024/08/aldo-store-sign-850.jpg',
#       'theme-color': '#ffffff',
#       'article:published_time': '2024-08-01T19:43:22+00:00',
#       'og:image:width': '850',
#       'twitter:card': 'summary_large_image',
#       'og:site_name': 'CX Today',
#       'apple-mobile-web-app-title': 'CX Today - Customer Experience Technology News',
#       'twitter:label1': 'Written by',
#       'twitter:label2': 'Estimated reading time',
#       'og:image:type': 'image/jpeg',
#       'msapplication-tileimage': '/ms-icon-144x144.png',
#       'og:description': 'CX Today covers Customer Data Platform news including Digital Transformation, Ecommerce, Generative AI, Retail and more.',
#       'twitter:creator': '@cxtodaynews',
#       'article:publisher': 'https://www.facebook.com/CXTodayNews/',
#       'twitter:data1': 'Charlie Mitchell',
#       'twitter:data2': '6 minutes',
#       'twitter:site': '@cxtodaynews',
#       'article:modified_time': '2024-08-05T14:44:37+00:00',
#       'msapplication-tilecolor': '#ffffff',
#       'og:type': 'article',
#       'author': 'Charlie Mitchell',
#       'og:title': "ALDO Group Prioritizes Predictive AI Over Generative AI. Here's Why.",
#       'og:image:height': '425',
#       'viewport': 'width=device-width, initial-scale=1, shrink-to-fit=no',
#       'apple-mobile-web-app-capable': 'yes',
#       'mobile-web-app-capable': 'yes',
#       'og:locale': 'en_GB',
#       'og:url': 'https://www.cxtoday.com/customer-data-platform/aldo-group-prioritizes-predictive-ai-over-generative-ai-heres-why/'}],
#     'cse_image': [{'src': 'https://www.cxtoday.com/wp-content/uploads/2024/08/aldo-store-sign-850.jpg'}]}},
#   {'kind': 'customsearch#result',
#    'title': "Inside ALDO's in-house generative AI and machine learning strategy ...",
#    'htmlTitle': 'Inside <b>ALDO&#39;s</b> in-house generative <b>AI</b> and machine learning strategy ...',
#    'link': 'https://digiday.com/marketing/inside-aldos-in-house-generative-ai-and-machine-learning-strategy/',
#    'displayLink': 'digiday.com',
#    'snippet': 'Jul 8, 2024 ... Amidst the artificial intelligence hype cycle, shoe and accessories retailer ALDO is working to lay its own internal AI foundations,\xa0...',
#    'htmlSnippet': 'Jul 8, 2024 <b>...</b> Amidst the <b>artificial intelligence</b> hype cycle, shoe and accessories retailer <b>ALDO</b> is working to lay its own internal <b>AI</b> foundations,&nbsp;...',
#    'formattedUrl': 'https://digiday.com/.../inside-aldos-in-house-generative-ai-and-machine-lea...',
#    'htmlFormattedUrl': 'https://digiday.com/.../inside-<b>aldo</b>s-in-house-generative-<b>ai</b>-and-machine-lea...',
#    'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSTKj0qh1fMHljHH21g3zaqCMyeNd4uXbvcMadHyPm5wbz6ysnMECxS-tw&s',
#       'width': '294',
#       'height': '171'}],
#     'metatags': [{'og:image': 'https://digiday.com/wp-content/uploads/sites/3/2024/06/ai-calendar-digiday.jpeg',
#       'msapplication-config': 'https://digiday.com/wp-content/themes/digiday/static/images/favicons/browserconfig.xml',
#       'article:published_time': '2024-07-08T04:01:00+00:00',
#       'og:image:width': '1030',
#       'twitter:card': 'summary_large_image',
#       'theme-color': '#ffffff',
#       'msapplication-square70x70logo': 'https://digiday.com/wp-content/themes/digiday/static/images/favicons/mstile-70x70.png',
#       'og:site_name': 'Digiday',
#       'apple-mobile-web-app-title': 'Digiday',
#       'twitter:label1': 'Written by',
#       'twitter:label2': 'Est. reading time',
#       'msapplication-wide310x150logo': 'https://digiday.com/wp-content/themes/digiday/static/images/favicons/mstile-310x150.png',
#       'og:image:type': 'image/jpeg',
#       'msapplication-tileimage': 'https://digiday.com/wp-content/themes/digiday/static/images/favicons/mstile-144x144.png',
#       'og:description': 'Amidst the artificial intelligence hype cycle, ALDO shoe and accessories retailer is working to lay its own internal AI foundations, expectant that tools goes from hopeful hypotheticals to mechanisms that deliver business results.',
#       'twitter:creator': '@digiday',
#       'article:publisher': 'https://www.facebook.com/digiday/',
#       'twitter:data1': 'Kimeko McCoy',
#       'twitter:data2': '4 minutes',
#       'twitter:site': '@digiday',
#       'msapplication-square310x310logo': 'https://digiday.com/wp-content/themes/digiday/static/images/favicons/mstile-310x310.png',
#       'application-name': 'Digiday',
#       'msapplication-tilecolor': '#FFFFFF',
#       'og:type': 'article',
#       'msvalidate.01': '36BBCBBC8FB6F9263E98BDCC0E4879E2',
#       'author': 'Kimeko McCoy',
#       'og:title': "Inside ALDO's in-house generative AI and machine learning strategy",
#       'og:image:height': '600',
#       'msapplication-square150x150logo': 'https://digiday.com/wp-content/themes/digiday/static/images/favicons/mstile-150x150.png',
#       'viewport': 'width=device-width, initial-scale=1',
#       'og:locale': 'en_US',
#       'og:url': 'https://digiday.com/marketing/inside-aldos-in-house-generative-ai-and-machine-learning-strategy/'}],
#     'cse_image': [{'src': 'https://digiday.com/wp-content/uploads/sites/3/2024/06/ai-calendar-digiday.jpeg'}]}},
#   {'kind': 'customsearch#result',
#    'title': 'ALDO Group | Contentful',
#    'htmlTitle': '<b>ALDO Group</b> | Contentful',
#    'link': 'https://www.contentful.com/case-studies/aldo-group/',
#    'displayLink': 'www.contentful.com',
#    'snippet': "Content plays a key role in the ALDO Group's ecommerce and retail strategies, and it was concerned about losing time when making content changes. With improving\xa0...",
#    'htmlSnippet': 'Content plays a key role in the <b>ALDO Group&#39;s</b> ecommerce and retail strategies, and it was concerned about losing time when making content changes. With improving&nbsp;...',
#    'formattedUrl': 'https://www.contentful.com/case-studies/aldo-group/',
#    'htmlFormattedUrl': 'https://www.contentful.com/case-studies/<b>aldo</b>-<b>group</b>/',
#    'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRtqvFNYX8cmZrm77R2So8AYZ12bwhercJUavTtyS-v_mqtOCUJdnhZAGz_&s',
#       'width': '310',
#       'height': '163'}],
#     'metatags': [{'date': '2024-07-02T21:51:03.336Z',
#       'og:image': 'https://images.ctfassets.net/jtqsy5pye0zd/54NhUPmKvUJ3tqIT7PS3uf/34ac8b293dbc40cb30ac13087b8de215/1200x630_with_logomark.png',
#       'og:type': 'website',
#       'twitter:card': 'summary',
#       'twitter:title': 'ALDO Group',
#       'csp-nonce': 'NjVhODBlODctZGZiNC00NzA3LWIzNzItZmUzNDNhZjhlZmE4',
#       'og:title': 'ALDO Group',
#       'og:description': "Learn how Contentful's composable content platform became the foundation of the ALDO Group’s digital strategy.",
#       'twitter:creator': '@contentful',
#       'zd-site-verification': '0t779dw7x0mriaomrvbp7ah',
#       'twitter:image': 'https://images.ctfassets.net/jtqsy5pye0zd/54NhUPmKvUJ3tqIT7PS3uf/34ac8b293dbc40cb30ac13087b8de215/1200x630_with_logomark.png',
#       'pathname': '/case-studies/aldo-group/',
#       'twitter:site': '@contentful',
#       'viewport': 'width=device-width, initial-scale=1',
#       'twitter:description': "Learn how Contentful's composable content platform became the foundation of the ALDO Group’s digital strategy.",
#       'og:url': 'https://www.contentful.com/case-studies/aldo-group/'}],
#     'cse_image': [{'src': 'https://images.ctfassets.net/jtqsy5pye0zd/54NhUPmKvUJ3tqIT7PS3uf/34ac8b293dbc40cb30ac13087b8de215/1200x630_with_logomark.png'}]}},
#   {'kind': 'customsearch#result',
#    'title': "Aldo's AI Investments Include Celebrity Picks and Demand ...",
#    'htmlTitle': '<b>Aldo&#39;s AI</b> Investments Include Celebrity Picks and Demand ...',
#    'link': 'https://consumergoods.com/aldos-ai-investments-include-celebrity-picks-and-demand-forecasting',
#    'displayLink': 'consumergoods.com',
#    'snippet': 'Jul 29, 2024 ... As part of its artificial intelligence exploration, Aldo has developed a demand forecasting machine learning model known as “Delphine” to\xa0...',
#    'htmlSnippet': 'Jul 29, 2024 <b>...</b> As part of its <b>artificial intelligence</b> exploration, <b>Aldo</b> has developed a demand forecasting machine learning model known as “Delphine” to&nbsp;...',
#    'formattedUrl': 'https://consumergoods.com/aldos-ai-investments-include-celebrity-picks-an...',
#    'htmlFormattedUrl': 'https://consumergoods.com/<b>aldo</b>s-<b>ai</b>-investments-include-celebrity-picks-an...',
#    'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTbfBYePOQ2aFjTfMwCS5-cyQwRVJ9wwXzag2QG3UyIVVXnZ4Kg_CSUmrM&s',
#       'width': '300',
#       'height': '168'}],
#     'metatags': [{'og:image': 'https://consumergoods.com/images/v/16_x_9_480/s3fs-public/2024-07/aldo_group_1735520864.jpg',
#       'og:type': 'Article',
#       'og:image:width': '655',
#       'og:image:alt': 'Aldo Group',
#       'twitter:card': 'summary_large_image',
#       'twitter:title': 'Aldo’s AI Investments Include Celebrity Picks and Demand Forecasting',
#       'og:site_name': 'Consumer Goods Technology',
#       'og:image:url': 'https://consumergoods.com/images/v/16_x_9_480/s3fs-public/2024-07/aldo_group_1735520864.jpg',
#       'og:title': 'Aldo’s AI Investments Include Celebrity Picks and Demand Forecasting',
#       'og:image:height': '368',
#       'og:image:type': 'image/jpeg',
#       'title': 'Aldo’s AI Investments Include Celebrity Picks and Demand Forecasting | Consumer Goods Technology',
#       'og:updated_time': '2025-01-10T15:54:33-0600',
#       'og:description': 'As part of its artificial intelligence exploration, Aldo has developed a\xa0demand forecasting machine learning model known as “Delphine” to help ensure inventory is available regardless of the channel, from in-store to TikTok Shop.',
#       'twitter:image': 'https://consumergoods.com/images/v/16_x_9_480/s3fs-public/2024-07/aldo_group_1735520864.jpg',
#       'twitter:image:alt': 'Aldo Group',
#       'viewport': 'width=device-width',
#       'twitter:description': 'As part of its artificial intelligence exploration, Aldo has developed a\xa0demand forecasting machine learning model known as “Delphine” to help ensure inventory is available regardless of the channel, from in-store to TikTok Shop.',
#       'og:url': 'https://consumergoods.com/aldos-ai-investments-include-celebrity-picks-and-demand-forecasting'}],
#     'cse_image': [{'src': 'https://consumergoods.com/images/v/16_x_9_480/s3fs-public/2024-07/aldo_group_1735520864.jpg'}]}},
#   {'kind': 'customsearch#result',
#    'title': 'How Aldo puts its best foot forward with a unified e-commerce ...',
#    'htmlTitle': 'How <b>Aldo</b> puts its best foot forward with a unified e-commerce ...',
#    'link': 'https://emarsys.com/why-emarsys/success-stories/how-aldo-puts-its-best-foot-forward-with-a-unified-e-commerce-system/',
#    'displayLink': 'emarsys.com',
#    'snippet': 'The Business. With its signature brands ALDO, Call It Spring, and GLOBO, ALDO Group Inc. lets consumers express their true selves through quality footwear,\xa0...',
#    'htmlSnippet': 'The Business. With its signature brands ALDO, Call It Spring, and GLOBO, <b>ALDO Group</b> Inc. lets consumers express their true selves through quality footwear,&nbsp;...',
#    'formattedUrl': 'https://emarsys.com/.../how-aldo-puts-its-best-foot-forward-with-a-unified-...',
#    'htmlFormattedUrl': 'https://emarsys.com/.../how-<b>aldo</b>-puts-its-best-foot-forward-with-a-unified-...',
#    'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT-L9Ai1eqwKOOleL_ZCGFw7hjCo3NM6vJamCCduvNORN32q1iBhZ8DJt4D&s',
#       'width': '311',
#       'height': '162'}],
#     'metatags': [{'og:image': 'https://emarsys.com/app/uploads/2024/04/Success_Story-Aldo-Feature-image-EN-v1.jpg',
#       'og:type': 'article',
#       'og:image:width': '1200',
#       'twitter:card': 'summary_large_image',
#       'og:site_name': 'SAP Emarsys',
#       'og:title': 'How Aldo puts its best foot forward with a unified e-commerce system',
#       'og:image:height': '628',
#       'twitter:label1': 'Est. reading time',
#       'og:image:type': 'image/jpeg',
#       'msapplication-tileimage': 'https://emarsys.com/app/uploads/2025/01/cropped-SAP_favicon-270x270.png',
#       'og:description': 'How ALDO connected customer behavior and preference data for a more holistic view, allowing for AI insights to improve product recommendations and customer experience.',
#       'article:publisher': 'https://www.facebook.com/emarsys/',
#       'twitter:data1': '6 minutes',
#       'facebook-domain-verification': 'gpz9h6h3yuzi8f7758kz7p2jxvk3jz',
#       'twitter:site': '@emarsys',
#       'article:modified_time': '2024-04-29T12:53:23+00:00',
#       'viewport': 'width=device-width, initial-scale=1, shrink-to-fit=no',
#       'og:locale': 'en_US',
#       'og:url': 'https://emarsys.com/why-emarsys/success-stories/how-aldo-puts-its-best-foot-forward-with-a-unified-e-commerce-system/'}],
#     'cse_image': [{'src': 'https://emarsys.com/app/uploads/2024/04/Success_Story-Aldo-Feature-image-EN-v1.jpg'}]}},
#   {'kind': 'customsearch#result',
#    'title': "ALDO Group's AI Revolution | Fatih Nayebi, Ph.D. posted on the ...",
#    'htmlTitle': '<b>ALDO Group&#39;s AI</b> Revolution | Fatih Nayebi, Ph.D. posted on the ...',
#    'link': 'https://www.linkedin.com/posts/thefatih_2023-impact-report-aldo-group-activity-7217538329657929729-TaQW',
#    'displayLink': 'www.linkedin.com',
#    'snippet': 'Jul 12, 2024 ... A comprehensive document showcasing the incredible work done last year at the ALDO Group to create responsible products, inspire a better tomorrow for everyone.',
#    'htmlSnippet': 'Jul 12, 2024 <b>...</b> A comprehensive document showcasing the incredible work done last year at the <b>ALDO Group</b> to create responsible products, inspire a better tomorrow for everyone.',
#    'formattedUrl': 'https://www.linkedin.com/.../thefatih_2023-impact-report-aldo-group-activi...',
#    'htmlFormattedUrl': 'https://www.linkedin.com/.../thefatih_2023-impact-report-<b>aldo</b>-<b>group</b>-activi...',
#    'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcReZZwU-Nj7Psst_HLlTt1mnnJPzL2RWdkIan0Ee9L-u1pereMyh2NU5lc&s',
#       'width': '297',
#       'height': '170'}],
#     'metatags': [{'og:image': 'https://static.licdn.com/aero-v1/sc/h/c45fy346jw096z9pbphyyhdz7',
#       'twitter:title': 'ALDO Group&#39;s AI Revolution | Fatih Nayebi, Ph.D. posted on the topic | LinkedIn',
#       'twitter:card': 'summary_large_image',
#       'og:type': 'article',
#       'al:ios:app_name': 'LinkedIn',
#       'twitter:url': 'https://www.linkedin.com/posts/thefatih_2023-impact-report-aldo-group-activity-7217538329657929729-TaQW',
#       'og:title': 'ALDO Group&#39;s AI Revolution | Fatih Nayebi, Ph.D. posted on the topic | LinkedIn',
#       'al:android:package': 'com.linkedin.android',
#       'pagekey': 'p_public_post',
#       'locale': 'en_US',
#       'al:ios:url': 'https://www.linkedin.com/posts/thefatih_2023-impact-report-aldo-group-activity-7217538329657929729-TaQW',
#       'og:description': '🌟 Our AI Revolution is Underway! 🌟\n\nI&#39;m delighted to share some advancements in AI at ALDO Group as depicted in our 2023 Impact Report (pages: 56 to 58)…',
#       'al:ios:app_store_id': '288429040',
#       'twitter:image': 'https://static.licdn.com/aero-v1/sc/h/c45fy346jw096z9pbphyyhdz7',
#       'al:android:url': 'https://www.linkedin.com/posts/thefatih_2023-impact-report-aldo-group-activity-7217538329657929729-TaQW',
#       'lnkd:url': 'https://www.linkedin.com/feed/update/urn:li:activity:7217538329657929729',
#       'twitter:site': '@linkedin',
#       'viewport': 'width=device-width, initial-scale=1.0',
#       'twitter:description': '🌟 Our AI Revolution is Underway! 🌟\n\nI&#39;m delighted to share some advancements in AI at ALDO Group as depicted in our 2023 Impact Report (pages: 56 to 58)…',
#       'og:url': 'https://www.linkedin.com/posts/thefatih_2023-impact-report-aldo-group-activity-7217538329657929729-TaQW',
#       'al:android:app_name': 'LinkedIn'}],
#     'cse_image': [{'src': 'https://static.licdn.com/aero-v1/sc/h/c45fy346jw096z9pbphyyhdz7'}]}},
#   {'kind': 'customsearch#result',
#    'title': 'DataSphere Lab & ALDO Group Partnership: Shaping the Future of ...',
#    'htmlTitle': 'DataSphere Lab &amp; <b>ALDO Group</b> Partnership: Shaping the Future of ...',
#    'link': 'https://www.mcgill.ca/bensadoun-school/data-sphere-lab/our-stakeholders/datasphere-lab-aldo-group-partnership',
#    'displayLink': 'www.mcgill.ca',
#    'snippet': "The DataSphere Lab (DSL) at McGill University's Desautels Faculty of Management, in collaboration with the Bensadoun School of Retail Management (BSRM) and\xa0...",
#    'htmlSnippet': 'The DataSphere Lab (DSL) at McGill University&#39;s Desautels Faculty of Management, in collaboration with the Bensadoun School of Retail Management (BSRM) and&nbsp;...',
#    'formattedUrl': 'https://www.mcgill.ca/bensadoun.../datasphere-lab-aldo-group-partnership',
#    'htmlFormattedUrl': 'https://www.mcgill.ca/bensadoun.../datasphere-lab-<b>aldo</b>-<b>group</b>-partnership',
#    'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSRFbyQRkO5NFLxpyfhC9u87tq02SJ6IaeL1eNgIL_b1ZtQk0XtRrKqvIQ&s',
#       'width': '275',
#       'height': '183'}],
#     'CollegeOrUniversity': [{'name': 'McGill University',
#       'url': 'https://www.mcgill.ca/',
#       'sameAs': 'http://www.facebook.com/McGillUniversity'}],
#     'metatags': [{'og:type': 'website',
#       'og:image:width': '300',
#       'twitter:card': 'summary_large_image',
#       'twitter:title': 'DataSphere Lab & ALDO Group Partnership: Shaping the Future of Retail',
#       'og:site_name': 'Bensadoun School of Retail Management',
#       'mcgill:tag': 'DataSphere Lab',
#       'og:title': 'DataSphere Lab & ALDO Group Partnership: Shaping the Future of Retail with AI',
#       'og:image:height': '300',
#       'mcgill:language': 'en',
#       'og:updated_time': '2024-05-02T10:08:41-04:00',
#       'og:description': 'The DataSphere Lab (DSL) at McGill University’s Desautels Faculty of Management, in collaboration with the Bensadoun School of Retail Management (BSRM) and the Master of Management in Analytics, has been instrumental in bridging the gap between industry and academia, fostering innovation at its finest. ALDO Group / AI-sthetics project A prime example is our involvement in the ALDO Group / AI-sthetics project. This groundbreaking initiative is a collaboration between the DataSphere Lab, five multi-disciplinary McGill University undergraduate students, ALDO Group, and AWS (Amazon Web Services).      Hackathon Launch   BSRM launches the inaugural Retail Gen AI Hackathon, with ALDO Group’s sponsorship and tech infrastructure provided by the DataSphere Lab.       Idea Selection   ALDO Group’s C Suite reviews 40 innovative solutions and selects one idea, AI-sthetics project, for further development.       Idea Development   The DataSphere Lab facilitates the project’s implementation phase alongside the stud',
#       'og:video:width': '300',
#       'twitter:image': 'https://www.mcgill.ca/sites/all/themes/moriarty/images/mcgill_crest.png',
#       'twitter:site': '@McGillU',
#       'mcgill:image:alt': 'Hackathon Launch',
#       'og:locale:alternate': 'fr_FR',
#       'viewport': 'width=device-width, initial-scale=1.0',
#       'twitter:description': 'The DataSphere Lab (DSL) at McGill University’s Desautels Faculty of Management, in collaboration with the Bensadoun School of Retail Management (BSRM) and the Master of Management in Analytics, has',
#       'mcgill:image:uri': 'https://www.mcgill.ca/bensadoun-school/files/bensadoun-school/styles/wysiwyg_large/public/dsl-initiatives-desat-500x333-1.jpg?itok=UnspFb6E',
#       'og:video:height': '250',
#       'og:url': 'https://www.mcgill.ca/bensadoun-school/data-sphere-lab/our-stakeholders/datasphere-lab-aldo-group-partnership',
#       'mcgill:pubdate': '2024-05-02T14:05:08Z'}],
#     'cse_image': [{'src': 'https://www.mcgill.ca/bensadoun-school/files/bensadoun-school/dsl-initiatives-desat-500x333-1.jpg'}]}},
#   {'kind': 'customsearch#result',
#    'title': 'SCALE AI is announcing investments of more than $20 million in 5 ...',
#    'htmlTitle': 'SCALE <b>AI</b> is announcing investments of more than $20 million in 5 ...',
#    'link': 'https://www.scaleai.ca/scale-ai-is-announcing-investments-of-more-than-20-million-in-5-ai-projects-for-intelligent-supply-chains/',
#    'displayLink': 'www.scaleai.ca',
#    'snippet': 'Sep 28, 2023 ... The ALDO Group, a leading Canadian fashion retailer, is currently using AI to develop a comprehensive solution aimed at automating key processes\xa0...',
#    'htmlSnippet': 'Sep 28, 2023 <b>...</b> The <b>ALDO Group</b>, a leading Canadian fashion retailer, is currently using <b>AI</b> to develop a comprehensive solution aimed at automating key processes&nbsp;...',
#    'formattedUrl': 'https://www.scaleai.ca/scale-ai-is-announcing-investments-of-more-than-20...',
#    'htmlFormattedUrl': 'https://www.scaleai.ca/scale-<b>ai</b>-is-announcing-investments-of-more-than-20...',
#    'pagemap': {'metatags': [{'theme-color': '#fff',
#       'og:type': 'article',
#       'article:published_time': '2023-09-28T15:24:56+00:00',
#       'og:site_name': 'Scale AI',
#       'og:locale:alternate': 'fr_CA',
#       'viewport': 'width=device-width, initial-scale=1.0, maximum-scale=1.0,user-scalable=0',
#       'author': 'Charlotte BA',
#       'og:title': 'SCALE AI is announcing investments of more than $20 million in 5 AI projects for intelligent supply chains',
#       'og:locale': 'en_US',
#       'og:url': 'https://www.scaleai.ca/scale-ai-is-announcing-investments-of-more-than-20-million-in-5-ai-projects-for-intelligent-supply-chains/',
#       'msapplication-tileimage': 'https://www.scaleai.ca/wp-content/uploads/2020/07/favicon.png',
#       'og:description': "SCALE AI a annoncé aujourd'hui, lors de l'événement ALL IN, des investissements totalisant plus de 20 millions de dollars pour cinq projets d'IA dans des secteurs économiques clés. En renforçant les chaînes d'approvisionnement grâce à des technologies alimentées par l'IA, ces solutions permettent aux entreprises de toutes tailles d'accroître leur productivité et leur efficacité."}]}},
#   {'kind': 'customsearch#result',
#    'title': 'Retail Gen AI Hackathon | Bensadoun School of Retail Management ...',
#    'htmlTitle': 'Retail Gen <b>AI</b> Hackathon | Bensadoun School of Retail Management ...',
#    'link': 'https://www.mcgill.ca/bensadoun-school/featured-events/retail-gen-ai-hackathon',
#    'displayLink': 'www.mcgill.ca',
#    'snippet': 'This first edition of the Retail Gen AI Hackathon, powered by ALDO Group, is a unique opportunity to work on a real-life problem, develop a solution in a\xa0...',
#    'htmlSnippet': 'This first edition of the Retail Gen <b>AI</b> Hackathon, powered by <b>ALDO Group</b>, is a unique opportunity to work on a real-life problem, develop a solution in a&nbsp;...',
#    'formattedUrl': 'https://www.mcgill.ca/bensadoun-school/featured.../retail-gen-ai-hackathon',
#    'htmlFormattedUrl': 'https://www.mcgill.ca/bensadoun-school/featured.../retail-gen-<b>ai</b>-hackathon',
#    'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQC6Jc63T1YDG_ZCvT9uQ9q56iLU5vg1LfP63qDzjmaTppLG_eIAY7PfxQ&s',
#       'width': '370',
#       'height': '136'}],
#     'CollegeOrUniversity': [{'name': 'McGill University',
#       'url': 'https://www.mcgill.ca/',
#       'sameAs': 'http://www.facebook.com/McGillUniversity'}],
#     'metatags': [{'og:type': 'website',
#       'og:image:width': '300',
#       'twitter:card': 'summary_large_image',
#       'twitter:title': 'Retail Gen AI Hackathon | Fall 2024',
#       'og:site_name': 'Bensadoun School of Retail Management',
#       'mcgill:tag': 'Retail Gen AI Hackathon',
#       'og:title': 'Retail Gen AI Hackathon | Fall 2024',
#       'og:image:height': '300',
#       'mcgill:language': 'en',
#       'og:updated_time': '2024-11-19T15:11:16-05:00',
#       'og:description': 'September 26 - October 4, 2024 The second edition of the Bensadoun School of Retail Management’s Retail Gen AI Hackathon in partnership with ALDO Group and powered by AWS, IVADO Labs, and the DataSphere Lab, was a unique opportunity to work on a real-life problem and learn how AI (Generative, Predictive, and Prescriptive) can help retailers make better data-driven decisions within their operations. Meet the winners We are proud to have been supported by the DataSphere Lab at McGill University who provided students with machine learning models and cloud-based resources that were essential to accomplish their goals. Here are the highlights from our event!  Video of Retail Gen AI Hackathon 2024 Want to work collaboratively in a fun yet competitive environment to develop innovative AI solutions for the ALDO Group? What to expect No need to have previous hacking and coding experience! Coaches and mentors from ALDO Group and AWS will be on-site during the final hacking phase to guide you with your proposed soluti',
#       'og:video:width': '300',
#       'twitter:image': 'https://www.mcgill.ca/sites/all/themes/moriarty/images/mcgill_crest.png',
#       'twitter:site': '@McGillU',
#       'og:locale:alternate': 'fr_FR',
#       'viewport': 'width=device-width, initial-scale=1.0',
#       'twitter:description': 'September 26 - October 4, 2024 The second edition of the Bensadoun School of Retail Management’s Retail Gen AI Hackathon in partnership with ALDO Group and powered by AWS, IVADO Labs, and the',
#       'og:video:height': '250',
#       'og:url': 'https://www.mcgill.ca/bensadoun-school/featured-events/retail-gen-ai-hackathon',
#       'mcgill:pubdate': '2024-11-19T20:11:11Z'}],
#     'cse_image': [{'src': 'https://www.mcgill.ca/bensadoun-school/files/bensadoun-school/styles/fullwidth_breakpoints_theme_moriarty_small_1x/public/hero/2024.07_bsrm_hackathon_web_bilingual_1900x700_en_d.png?itok=TzsnF3WG&timestamp=1725474995'}]}}]}

# %%
def parse_date(raw_date):
    """Convert various date formats to dd-mm-yyyy"""
    try:
        # Clean up common date string issues
        raw_date = raw_date.strip().replace('\n', ' ')
        
        # Handle ISO format dates with time (e.g., "2023-12-31T15:30:00Z")
        iso_match = re.match(r'(\d{4}-\d{2}-\d{2})', raw_date)
        if iso_match:
            raw_date = iso_match.group(1)
        
        # Define priority order of date formats to try
        date_formats = [
            '%Y-%m-%d',        # ISO format
            '%d %B %Y',        # 25 December 2023
            '%B %d, %Y',       # December 25, 2023
            '%b %d, %Y',       # Dec 25, 2023
            '%d/%m/%Y',        # 25/12/2023
            '%m/%d/%Y',        # 12/25/2023
            '%d-%m-%Y',        # 25-12-2023
            '%m-%d-%Y',        # 12-25-2023
            '%d.%m.%Y',        # 25.12.2023
            '%Y%m%d',          # 20231225
        ]
        
        for fmt in date_formats:
            try:
                parsed_date = datetime.strptime(raw_date, fmt)
                return parsed_date.strftime('%d-%m-%Y')
            except ValueError:
                continue
                
        return "Unrecognized format"
    except Exception as e:
        return f"Date parse error: {str(e)}"

def extract_date_from_url(url):
    try:
        headers = {"User-Agent": "Mozilla/5.0"}
        response = requests.get(url, headers=headers, timeout=10)
        soup = BeautifulSoup(response.text, "html.parser")
        
        # 1. Check meta tags first (most reliable)
        meta_properties = [
            ('article:published_time', None),
            ('og:published_time', None),
            ('date', None),
            ('DC.date.issued', 'name'),
            ('PublicationDate', 'name')
        ]
        
        for prop, attr in meta_properties:
            meta = soup.find('meta', {attr or 'property': prop})
            if meta and meta.get('content'):
                return parse_date(meta['content'])
        
        # 2. Search visible text patterns
        months = r"|".join([
            "January", "February", "March", "April", "May", "June",
            "July", "August", "September", "October", "November", "December",
            "Jan", "Feb", "Mar", "Apr", "May", "Jun",
            "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"
        ])
        
        patterns = [
            r'\d{4}-\d{2}-\d{2}',                      # ISO dates
            r'\d{1,2}/\d{1,2}/\d{4}',                   # US/UK dates
            fr'({months})[\s,]+(\d{{1,2}})[\s,]+(\d{{4}})',  # Month name dates
            r'\d{1,2}\.\d{1,2}\.\d{4}',                 # European date format
            r'\d{{1,2}}\s+(?:st|nd|rd|th)\s+{months}\s+\d{{4}}'  # "25th December 2023"
        ]
        
        for pattern in patterns:
            matches = re.finditer(pattern, soup.get_text(), re.IGNORECASE)
            for match in matches:
                date_str = match.group().replace(',', '').strip()
                parsed = parse_date(date_str)
                if "error" not in parsed.lower():
                    return parsed
        
        return "Date not found"
   
    except Exception as e:
        return f"Error fetching date: {str(e)}"


for item in data.get("items", []):
    url = item.get("link")
    date = extract_date_from_url(url)
    print(f"Title: {item.get('title')}")
    print(f"Date: {date}\n")
# Out:
# Title: ALDO Group Invests in Predictive AI for Demand Forecasting - ASUG
# Date: Unrecognized format
#
# Title: ALDO Group Prioritizes Predictive AI Over Generative AI. Here's ...
# Date: Date not found
#
# Title: Inside ALDO's in-house generative AI and machine learning strategy ...
# Date: 08-07-2024
#
# Title: ALDO Group | Contentful
# Date: Date not found
#
# Title: Aldo's AI Investments Include Celebrity Picks and Demand ...
# Date: 29-07-2024
#
# Title: How Aldo puts its best foot forward with a unified e-commerce ...
# Date: Unrecognized format
#
# Title: ALDO Group's AI Revolution | Fatih Nayebi, Ph.D. posted on the ...
# Date: Date not found
#
# Title: DataSphere Lab & ALDO Group Partnership: Shaping the Future of ...
# Date: Date not found
#
# Title: SCALE AI is announcing investments of more than $20 million in 5 ...
# Date: 28-09-2023
#
# Title: Retail Gen AI Hackathon | Bensadoun School of Retail Management ...
# Date: Unrecognized format

# %%
# Add dates to the dataframe
df = pd.DataFrame(data['items'])
df['date'] = df['link'].apply(extract_date_from_url)
keep = ["title", "date", "link", "displayLink", "snippet"]
df = df[keep] if not df.empty else pd.DataFrame(columns=keep)

df
# Out:
#                                                title                 date  \
# 0  ALDO Group Invests in Predictive AI for Demand...  Unrecognized format
# 1  ALDO Group Prioritizes Predictive AI Over Gene...       Date not found
# 2  Inside ALDO's in-house generative AI and machi...           08-07-2024
# 3                            ALDO Group | Contentful       Date not found
# 4  Aldo's AI Investments Include Celebrity Picks ...           29-07-2024
# 5  How Aldo puts its best foot forward with a uni...  Unrecognized format
# 6  ALDO Group's AI Revolution | Fatih Nayebi, Ph....       Date not found
# 7  DataSphere Lab & ALDO Group Partnership: Shapi...       Date not found
# 8  SCALE AI is announcing investments of more tha...           28-09-2023
# 9  Retail Gen AI Hackathon | Bensadoun School of ...  Unrecognized format
#
#                                                 link         displayLink  \
# 0  https://www.asug.com/insights/aldo-group-inves...        www.asug.com
# 1  https://www.cxtoday.com/customer-data-platform...     www.cxtoday.com
# 2  https://digiday.com/marketing/inside-aldos-in-...         digiday.com
# 3  https://www.contentful.com/case-studies/aldo-g...  www.contentful.com
# 4  https://consumergoods.com/aldos-ai-investments...   consumergoods.com
# 5  https://emarsys.com/why-emarsys/success-storie...         emarsys.com
# 6  https://www.linkedin.com/posts/thefatih_2023-i...    www.linkedin.com
# 7  https://www.mcgill.ca/bensadoun-school/data-sp...       www.mcgill.ca
# 8  https://www.scaleai.ca/scale-ai-is-announcing-...      www.scaleai.ca
# 9  https://www.mcgill.ca/bensadoun-school/feature...       www.mcgill.ca
#
#                                              snippet
# 0  Aug 16, 2024 ... ALDO Group is helping to deve...
# 1  Aug 1, 2024 ... Matthieu Houle, CIO of ALDO Gr...
# 2  Jul 8, 2024 ... Amidst the artificial intellig...
# 3  Content plays a key role in the ALDO Group's e...
# 4  Jul 29, 2024 ... As part of its artificial int...
# 5  The Business. With its signature brands ALDO, ...
# 6  Jul 12, 2024 ... A comprehensive document show...
# 7  The DataSphere Lab (DSL) at McGill University'...
# 8  Sep 28, 2023 ... The ALDO Group, a leading Can...
# 9  This first edition of the Retail Gen AI Hackat...

# %%
# Function to fetch text after the title
def get_text(url, title):
    try:
        response = requests.get(url, headers=headers, timeout=15)
        response.raise_for_status()
        soup = BeautifulSoup(response.text, "html.parser")
        
        # Extract text from all relevant tags
        text_elements = soup.find_all(['p', 'div', 'span'])
        text = " ".join([element.get_text() for element in text_elements])
        
        # Split the text into words
        words = text.split()
        
        # Try to find the title in the text
        title_words = title.split()
        title_index = None

        for i in range(len(words) - len(title_words) + 1):
            if words[i:i + len(title_words)] == title_words:
                title_index = i + len(title_words)  # Start after title
                break

        # If title found, extract 300 words after it
        if title_index is not None and title_index + 300 < len(words):
            return " ".join(words[title_index:title_index + 300])
        else:
            return " ".join(words[:300])  # Fallback: First 300 words
    
    except Exception as e:
        print(f"Error fetching text from {url}: {e}")
        return None
    
# call the function
url = [link for link in df["link"]]
# take first five words in the title and make single string
title_5 = [" ".join(title.split()[:5]) for title in df["title"]]


# Get text in url and add to the dataframe
df["body"] = [get_text(url, title) for url, title in zip(url, title_5)]
df
# Out:
# Error fetching text from https://www.cxtoday.com/customer-data-platform/aldo-group-prioritizes-predictive-ai-over-generative-ai-heres-why/: 403 Client Error: Forbidden for url: https://www.cxtoday.com/customer-data-platform/aldo-group-prioritizes-predictive-ai-over-generative-ai-heres-why/
#                                                title                 date  \
# 0  ALDO Group Invests in Predictive AI for Demand...  Unrecognized format
# 1  ALDO Group Prioritizes Predictive AI Over Gene...       Date not found
# 2  Inside ALDO's in-house generative AI and machi...           08-07-2024
# 3                            ALDO Group | Contentful       Date not found
# 4  Aldo's AI Investments Include Celebrity Picks ...           29-07-2024
# 5  How Aldo puts its best foot forward with a uni...  Unrecognized format
# 6  ALDO Group's AI Revolution | Fatih Nayebi, Ph....       Date not found
# 7  DataSphere Lab & ALDO Group Partnership: Shapi...       Date not found
# 8  SCALE AI is announcing investments of more tha...           28-09-2023
# 9  Retail Gen AI Hackathon | Bensadoun School of ...  Unrecognized format
#
#                                                 link         displayLink  \
# 0  https://www.asug.com/insights/aldo-group-inves...        www.asug.com
# 1  https://www.cxtoday.com/customer-data-platform...     www.cxtoday.com
# 2  https://digiday.com/marketing/inside-aldos-in-...         digiday.com
# 3  https://www.contentful.com/case-studies/aldo-g...  www.contentful.com
# 4  https://consumergoods.com/aldos-ai-investments...   consumergoods.com
# 5  https://emarsys.com/why-emarsys/success-storie...         emarsys.com
# 6  https://www.linkedin.com/posts/thefatih_2023-i...    www.linkedin.com
# 7  https://www.mcgill.ca/bensadoun-school/data-sp...       www.mcgill.ca
# 8  https://www.scaleai.ca/scale-ai-is-announcing-...      www.scaleai.ca
# 9  https://www.mcgill.ca/bensadoun-school/feature...       www.mcgill.ca
#
#                                              snippet  \
# 0  Aug 16, 2024 ... ALDO Group is helping to deve...
# 1  Aug 1, 2024 ... Matthieu Houle, CIO of ALDO Gr...
# 2  Jul 8, 2024 ... Amidst the artificial intellig...
# 3  Content plays a key role in the ALDO Group's e...
# 4  Jul 29, 2024 ... As part of its artificial int...
# 5  The Business. With its signature brands ALDO, ...
# 6  Jul 12, 2024 ... A comprehensive document show...
# 7  The DataSphere Lab (DSL) at McGill University'...
# 8  Sep 28, 2023 ... The ALDO Group, a leading Can...
# 9  This first edition of the Retail Gen AI Hackat...
#
#                                                 body
# 0  AI for Demand Forecasting Author ASUG Staff Pu...
# 1                                               None
# 2  Subscribe | Login Reader Digiday+ Member Subsc...
# 3  LivestreamJoin us March 31 as we unveil the fu...
# 4  Subscribe Subscribe Subscribe Subscribe News L...
# 5  foot forward with a unified e-commerce system ...
# 6  LinkedIn and 3rd parties use essential and non...
# 7  Partnership Retail Gen AI Hackathon Our Team C...
# 8  of more than $20 million in 5 AI projects for ...
# 9  Fall 2024 September 26 - October 4, 2024 The s...

# %%
# save the dataframe to csv
df.to_csv("output data/aldo_AI_search_results.csv", index=False)

# %% [markdown]
# ## Data Preprocessing

# %%
import nltk
from nltk.corpus import stopwords, names
from nltk.tokenize import word_tokenize
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords, names
from nltk.tokenize import word_tokenize
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer

import pandas as pd
import nltk
import re
import string
from nltk.corpus import stopwords, names
from nltk.tokenize import word_tokenize


import string
import re


#nltk.download('stopwords')
#nltk.download('names')
#nltk.download('punkt')
#nltk.download('punkt_tab')

# %%
search_results = pd.read_csv("output data/aldo_AI_search_results.csv")

# Drop rows where body is missing
search_results = search_results.dropna(subset=["body"])

search_results.shape
# Out:
# (9, 6)

# %%
stop_words = set(stopwords.words('english'))
names_dict = set(names.words())
names_dict = {key.lower() for key in names_dict}

print("Names in the dictionary: ", list(names_dict)[:10], "etc")
print("Stop words in the dictionary: ", list(stop_words)[:10], "etc")
# Out:
# Names in the dictionary:  ['dwaine', 'josephina', 'amory', 'jacky', 'webb', 'wood', 'joselyn', 'leo', 'corabelle', 'elvin'] etc
# Stop words in the dictionary:  ['here', 't', 'these', 'were', 'on', 'not', 'y', 'shouldn', 'when', "i've"] etc

# %%
stop_words = set(stopwords.words('english'))
names_dict = set(names.words())

def clean_text(text):
    if not isinstance(text, str):
        return ""
    
    # Text cleaning steps
    text = re.sub(r"[^a-zA-Z0-9.']+", " ", text)
    text = text.lower()
    text = re.sub(r"\d+(\.\d+)?%", " ", text)
    text = re.sub(r"\b\d+(\.\d+)?\b", " ", text)
    text = re.sub(r"www\.[^\s]+", "", text)
    text = re.sub(r"http[^\s]+", "", text)
    text = re.sub(r"\b\S*\.com\b", "", text)
    text = text.translate(str.maketrans('', '', string.punctuation))
    text = re.sub(r"\s+", " ", text).strip()
    
    words = word_tokenize(text)
    words = [word for word in words 
             if word not in stop_words
             and word not in names_dict
             and word.capitalize() not in names_dict]
    
    return " ".join(words)

# Clean the text data
search_results['cleaned_text'] = search_results['body'].fillna('').apply(clean_text)

# Save results
#df.to_csv("cleaned_data.csv", index=False)

search_results
# Out:
#                                                title                 date  \
# 0  ALDO Group Invests in Predictive AI for Demand...  Unrecognized format
# 2  Inside ALDO's in-house generative AI and machi...           08-07-2024
# 3                            ALDO Group | Contentful       Date not found
# 4  Aldo's AI Investments Include Celebrity Picks ...           29-07-2024
# 5  How Aldo puts its best foot forward with a uni...  Unrecognized format
# 6  ALDO Group's AI Revolution | Fatih Nayebi, Ph....       Date not found
# 7  DataSphere Lab & ALDO Group Partnership: Shapi...       Date not found
# 8  SCALE AI is announcing investments of more tha...           28-09-2023
# 9  Retail Gen AI Hackathon | Bensadoun School of ...  Unrecognized format
#
#                                                 link         displayLink  \
# 0  https://www.asug.com/insights/aldo-group-inves...        www.asug.com
# 2  https://digiday.com/marketing/inside-aldos-in-...         digiday.com
# 3  https://www.contentful.com/case-studies/aldo-g...  www.contentful.com
# 4  https://consumergoods.com/aldos-ai-investments...   consumergoods.com
# 5  https://emarsys.com/why-emarsys/success-storie...         emarsys.com
# 6  https://www.linkedin.com/posts/thefatih_2023-i...    www.linkedin.com
# 7  https://www.mcgill.ca/bensadoun-school/data-sp...       www.mcgill.ca
# 8  https://www.scaleai.ca/scale-ai-is-announcing-...      www.scaleai.ca
# 9  https://www.mcgill.ca/bensadoun-school/feature...       www.mcgill.ca
#
#                                              snippet  \
# 0  Aug 16, 2024 ... ALDO Group is helping to deve...
# 2  Jul 8, 2024 ... Amidst the artificial intellig...
# 3  Content plays a key role in the ALDO Group's e...
# 4  Jul 29, 2024 ... As part of its artificial int...
# 5  The Business. With its signature brands ALDO, ...
# 6  Jul 12, 2024 ... A comprehensive document show...
# 7  The DataSphere Lab (DSL) at McGill University'...
# 8  Sep 28, 2023 ... The ALDO Group, a leading Can...
# 9  This first edition of the Retail Gen AI Hackat...
#
#                                                 body  \
# 0  AI for Demand Forecasting Author ASUG Staff Pu...
# 2  Subscribe | Login Reader Digiday+ Member Subsc...
# 3  LivestreamJoin us March 31 as we unveil the fu...
# 4  Subscribe Subscribe Subscribe Subscribe News L...
# 5  foot forward with a unified e-commerce system ...
# 6  LinkedIn and 3rd parties use essential and non...
# 7  Partnership Retail Gen AI Hackathon Our Team C...
# 8  of more than $20 million in 5 AI projects for ...
# 9  Fall 2024 September 26 - October 4, 2024 The s...
#
#                                         cleaned_text
# 0  ai demand forecasting author asug staff publis...
# 2  subscribe login reader digiday member subscrib...
# 3  livestreamjoin us march unveil future digital ...
# 4  subscribe subscribe subscribe subscribe news l...
# 5  foot forward unified e commerce system puts be...
# 6  linkedin 3rd parties use essential non essenti...
# 7  partnership retail ai hackathon team contact u...
# 8  million ai projects intelligent supply chains ...
# 9  fall september october second edition bensadou...

# %%
def lemma_stem_text(text):
    # Tokenize the text
    words = word_tokenize(text)
    
    # Lemmatize the words
    lemmatizer = WordNetLemmatizer()
    words = [lemmatizer.lemmatize(word) for word in words]
    
    # Stem the words
    stemmer = PorterStemmer()
    words = [stemmer.stem(word) for word in words]
    
    return " ".join(words)

# Apply the function to the cleaned text
search_results["lemmatized_stemmed_text"] = search_results["cleaned_text"].apply(lemma_stem_text)
search_results
# Out:
#                                                title                 date  \
# 0  ALDO Group Invests in Predictive AI for Demand...  Unrecognized format
# 2  Inside ALDO's in-house generative AI and machi...           08-07-2024
# 3                            ALDO Group | Contentful       Date not found
# 4  Aldo's AI Investments Include Celebrity Picks ...           29-07-2024
# 5  How Aldo puts its best foot forward with a uni...  Unrecognized format
# 6  ALDO Group's AI Revolution | Fatih Nayebi, Ph....       Date not found
# 7  DataSphere Lab & ALDO Group Partnership: Shapi...       Date not found
# 8  SCALE AI is announcing investments of more tha...           28-09-2023
# 9  Retail Gen AI Hackathon | Bensadoun School of ...  Unrecognized format
#
#                                                 link         displayLink  \
# 0  https://www.asug.com/insights/aldo-group-inves...        www.asug.com
# 2  https://digiday.com/marketing/inside-aldos-in-...         digiday.com
# 3  https://www.contentful.com/case-studies/aldo-g...  www.contentful.com
# 4  https://consumergoods.com/aldos-ai-investments...   consumergoods.com
# 5  https://emarsys.com/why-emarsys/success-storie...         emarsys.com
# 6  https://www.linkedin.com/posts/thefatih_2023-i...    www.linkedin.com
# 7  https://www.mcgill.ca/bensadoun-school/data-sp...       www.mcgill.ca
# 8  https://www.scaleai.ca/scale-ai-is-announcing-...      www.scaleai.ca
# 9  https://www.mcgill.ca/bensadoun-school/feature...       www.mcgill.ca
#
#                                              snippet  \
# 0  Aug 16, 2024 ... ALDO Group is helping to deve...
# 2  Jul 8, 2024 ... Amidst the artificial intellig...
# 3  Content plays a key role in the ALDO Group's e...
# 4  Jul 29, 2024 ... As part of its artificial int...
# 5  The Business. With its signature brands ALDO, ...
# 6  Jul 12, 2024 ... A comprehensive document show...
# 7  The DataSphere Lab (DSL) at McGill University'...
# 8  Sep 28, 2023 ... The ALDO Group, a leading Can...
# 9  This first edition of the Retail Gen AI Hackat...
#
#                                                 body  \
# 0  AI for Demand Forecasting Author ASUG Staff Pu...
# 2  Subscribe | Login Reader Digiday+ Member Subsc...
# 3  LivestreamJoin us March 31 as we unveil the fu...
# 4  Subscribe Subscribe Subscribe Subscribe News L...
# 5  foot forward with a unified e-commerce system ...
# 6  LinkedIn and 3rd parties use essential and non...
# 7  Partnership Retail Gen AI Hackathon Our Team C...
# 8  of more than $20 million in 5 AI projects for ...
# 9  Fall 2024 September 26 - October 4, 2024 The s...
#
#                                         cleaned_text  \
# 0  ai demand forecasting author asug staff publis...
# 2  subscribe login reader digiday member subscrib...
# 3  livestreamjoin us march unveil future digital ...
# 4  subscribe subscribe subscribe subscribe news l...
# 5  foot forward unified e commerce system puts be...
# 6  linkedin 3rd parties use essential non essenti...
# 7  partnership retail ai hackathon team contact u...
# 8  million ai projects intelligent supply chains ...
# 9  fall september october second edition bensadou...
#
#                              lemmatized_stemmed_text
# 0  ai demand forecast author asug staff publish r...
# 2  subscrib login reader digiday member subscrib ...
# 3  livestreamjoin u march unveil futur digit expe...
# 4  subscrib subscrib subscrib subscrib news lates...
# 5  foot forward unifi e commerc system put best f...
# 6  linkedin 3rd parti use essenti non essenti coo...
# 7  partnership retail ai hackathon team contact u...
# 8  million ai project intellig suppli chain back ...
# 9  fall septemb octob second edit bensadoun schoo...

# %%
# Save the results
search_results.to_csv("output data/preprocessed_aldo_AI_search_results.csv", index=False)

# %% [markdown]
# ## Sentiment Analysis

# %% [markdown]
# ## About VADER and TextBlob
# * VADER was initially used for social media text analytics. It is even able to handle emojis!
#     - VADER is lexicon based
# * TextBlob is strong at analyzing longer text.
#     - TextBlob is rule based
#
# Both score ranges are between -1 (negative sentiment) and 1 (positive sentiment)

# %%
from textblob import TextBlob
from nltk.sentiment import SentimentIntensityAnalyzer

#nltk.download('vader_lexicon')

# %%
# look at vader_lexicon
sia = SentimentIntensityAnalyzer()
sia.lexicon
# Out:
# {'$:': -1.5,
#  '%)': -0.4,
#  '%-)': -1.5,
#  '&-:': -0.4,
#  '&:': -0.7,
#  "( '}{' )": 1.6,
#  '(%': -0.9,
#  "('-:": 2.2,
#  "(':": 2.3,
#  '((-:': 2.1,
#  '(*': 1.1,
#  '(-%': -0.7,
#  '(-*': 1.3,
#  '(-:': 1.6,
#  '(-:0': 2.8,
#  '(-:<': -0.4,
#  '(-:o': 1.5,
#  '(-:O': 1.5,
#  '(-:{': -0.1,
#  '(-:|>*': 1.9,
#  '(-;': 1.3,
#  '(-;|': 2.1,
#  '(8': 2.6,
#  '(:': 2.2,
#  '(:0': 2.4,
#  '(:<': -0.2,
#  '(:o': 2.5,
#  '(:O': 2.5,
#  '(;': 1.1,
#  '(;<': 0.3,
#  '(=': 2.2,
#  '(?:': 2.1,
#  '(^:': 1.5,
#  '(^;': 1.5,
#  '(^;0': 2.0,
#  '(^;o': 1.9,
#  '(o:': 1.6,
#  ")':": -2.0,
#  ")-':": -2.1,
#  ')-:': -2.1,
#  ')-:<': -2.2,
#  ')-:{': -2.1,
#  '):': -1.8,
#  '):<': -1.9,
#  '):{': -2.3,
#  ');<': -2.6,
#  '*)': 0.6,
#  '*-)': 0.3,
#  '*-:': 2.1,
#  '*-;': 2.4,
#  '*:': 1.9,
#  '*<|:-)': 1.6,
#  '*\\0/*': 2.3,
#  '*^:': 1.6,
#  ',-:': 1.2,
#  "---'-;-{@": 2.3,
#  '--<--<@': 2.2,
#  '.-:': -1.2,
#  '..###-:': -1.7,
#  '..###:': -1.9,
#  '/-:': -1.3,
#  '/:': -1.3,
#  '/:<': -1.4,
#  '/=': -0.9,
#  '/^:': -1.0,
#  '/o:': -1.4,
#  '0-8': 0.1,
#  '0-|': -1.2,
#  '0:)': 1.9,
#  '0:-)': 1.4,
#  '0:-3': 1.5,
#  '0:03': 1.9,
#  '0;^)': 1.6,
#  '0_o': -0.3,
#  '10q': 2.1,
#  '1337': 2.1,
#  '143': 3.2,
#  '1432': 2.6,
#  '14aa41': 2.4,
#  '182': -2.9,
#  '187': -3.1,
#  '2g2b4g': 2.8,
#  '2g2bt': -0.1,
#  '2qt': 2.1,
#  '3:(': -2.2,
#  '3:)': 0.5,
#  '3:-(': -2.3,
#  '3:-)': -1.4,
#  '4col': -2.2,
#  '4q': -3.1,
#  '5fs': 1.5,
#  '8)': 1.9,
#  '8-d': 1.7,
#  '8-o': -0.3,
#  '86': -1.6,
#  '8d': 2.9,
#  ':###..': -2.4,
#  ':$': -0.2,
#  ':&': -0.6,
#  ":'(": -2.2,
#  ":')": 2.3,
#  ":'-(": -2.4,
#  ":'-)": 2.7,
#  ':(': -1.9,
#  ':)': 2.0,
#  ':*': 2.5,
#  ':-###..': -2.5,
#  ':-&': -0.5,
#  ':-(': -1.5,
#  ':-)': 1.3,
#  ':-))': 2.8,
#  ':-*': 1.7,
#  ':-,': 1.1,
#  ':-.': -0.9,
#  ':-/': -1.2,
#  ':-<': -1.5,
#  ':-d': 2.3,
#  ':-D': 2.3,
#  ':-o': 0.1,
#  ':-p': 1.5,
#  ':-[': -1.6,
#  ':-\\': -0.9,
#  ':-c': -1.3,
#  ':-|': -0.7,
#  ':-||': -2.5,
#  ':-Þ': 0.9,
#  ':/': -1.4,
#  ':3': 2.3,
#  ':<': -2.1,
#  ':>': 2.1,
#  ':?)': 1.3,
#  ':?c': -1.6,
#  ':@': -2.5,
#  ':d': 2.3,
#  ':D': 2.3,
#  ':l': -1.7,
#  ':o': -0.4,
#  ':p': 1.4,
#  ':s': -1.2,
#  ':[': -2.0,
#  ':\\': -1.3,
#  ':]': 2.2,
#  ':^)': 2.1,
#  ':^*': 2.6,
#  ':^/': -1.2,
#  ':^\\': -1.0,
#  ':^|': -1.0,
#  ':c': -2.1,
#  ':c)': 2.0,
#  ':o)': 2.1,
#  ':o/': -1.4,
#  ':o\\': -1.1,
#  ':o|': -0.6,
#  ':{': -1.9,
#  ':|': -0.4,
#  ':}': 2.1,
#  ':Þ': 1.1,
#  ';)': 0.9,
#  ';-)': 1.0,
#  ';-*': 2.2,
#  ';-]': 0.7,
#  ';d': 0.8,
#  ';D': 0.8,
#  ';]': 0.6,
#  ';^)': 1.4,
#  '</3': -3.0,
#  '<3': 1.9,
#  '<:': 2.1,
#  '<:-|': -1.4,
#  '=)': 2.2,
#  '=-3': 2.0,
#  '=-d': 2.4,
#  '=-D': 2.4,
#  '=/': -1.4,
#  '=3': 2.1,
#  '=d': 2.3,
#  '=D': 2.3,
#  '=l': -1.2,
#  '=\\': -1.2,
#  '=]': 1.6,
#  '=p': 1.3,
#  '=|': -0.8,
#  '>-:': -2.0,
#  '>.<': -1.3,
#  '>:': -2.1,
#  '>:(': -2.7,
#  '>:)': 0.4,
#  '>:-(': -2.7,
#  '>:-)': -0.4,
#  '>:/': -1.6,
#  '>:o': -1.2,
#  '>:p': 1.0,
#  '>:[': -2.1,
#  '>:\\': -1.7,
#  '>;(': -2.9,
#  '>;)': 0.1,
#  '>_>^': 2.1,
#  '@:': -2.1,
#  '@>-->--': 2.1,
#  "@}-;-'---": 2.2,
#  'aas': 2.5,
#  'aayf': 2.7,
#  'afu': -2.9,
#  'alol': 2.8,
#  'ambw': 2.9,
#  'aml': 3.4,
#  'atab': -1.9,
#  'awol': -1.3,
#  'ayc': 0.2,
#  'ayor': -1.2,
#  'aug-00': 0.3,
#  'bfd': -2.7,
#  'bfe': -2.6,
#  'bff': 2.9,
#  'bffn': 1.0,
#  'bl': 2.3,
#  'bsod': -2.2,
#  'btd': -2.1,
#  'btdt': -0.1,
#  'bz': 0.4,
#  'b^d': 2.6,
#  'cwot': -2.3,
#  "d-':": -2.5,
#  'd8': -3.2,
#  'd:': 1.2,
#  'd:<': -3.2,
#  'd;': -2.9,
#  'd=': 1.5,
#  'doa': -2.3,
#  'dx': -3.0,
#  'ez': 1.5,
#  'fav': 2.0,
#  'fcol': -1.8,
#  'ff': 1.8,
#  'ffs': -2.8,
#  'fkm': -2.4,
#  'foaf': 1.8,
#  'ftw': 2.0,
#  'fu': -3.7,
#  'fubar': -3.0,
#  'fwb': 2.5,
#  'fyi': 0.8,
#  'fysa': 0.4,
#  'g1': 1.4,
#  'gg': 1.2,
#  'gga': 1.7,
#  'gigo': -0.6,
#  'gj': 2.0,
#  'gl': 1.3,
#  'gla': 2.5,
#  'gn': 1.2,
#  'gr8': 2.7,
#  'grrr': -0.4,
#  'gt': 1.1,
#  'h&k': 2.3,
#  'hagd': 2.2,
#  'hagn': 2.2,
#  'hago': 1.2,
#  'hak': 1.9,
#  'hand': 2.2,
#  'hho1/2k': 1.4,
#  'hhoj': 2.0,
#  'hhok': 0.9,
#  'hugz': 2.0,
#  'hi5': 1.9,
#  'idk': -0.4,
#  'ijs': 0.7,
#  'ilu': 3.4,
#  'iluaaf': 2.7,
#  'ily': 3.4,
#  'ily2': 2.6,
#  'iou': 0.7,
#  'iyq': 2.3,
#  'j/j': 2.0,
#  'j/k': 1.6,
#  'j/p': 1.4,
#  'j/t': -0.2,
#  'j/w': 1.0,
#  'j4f': 1.4,
#  'j4g': 1.7,
#  'jho': 0.8,
#  'jhomf': 1.0,
#  'jj': 1.0,
#  'jk': 0.9,
#  'jp': 0.8,
#  'jt': 0.9,
#  'jw': 1.6,
#  'jealz': -1.2,
#  'k4y': 2.3,
#  'kfy': 2.3,
#  'kia': -3.2,
#  'kk': 1.5,
#  'kmuf': 2.2,
#  'l': 2.0,
#  'l&r': 2.2,
#  'laoj': 1.3,
#  'lmao': 2.9,
#  'lmbao': 1.8,
#  'lmfao': 2.5,
#  'lmso': 2.7,
#  'lol': 1.8,
#  'lolz': 2.7,
#  'lts': 1.6,
#  'ly': 2.6,
#  'ly4e': 2.7,
#  'lya': 3.3,
#  'lyb': 3.0,
#  'lyl': 3.1,
#  'lylab': 2.7,
#  'lylas': 2.6,
#  'lylb': 1.6,
#  'm8': 1.4,
#  'mia': -1.2,
#  'mml': 2.0,
#  'mofo': -2.4,
#  'muah': 2.3,
#  'mubar': -1.0,
#  'musm': 0.9,
#  'mwah': 2.5,
#  'n1': 1.9,
#  'nbd': 1.3,
#  'nbif': -0.5,
#  'nfc': -2.7,
#  'nfw': -2.4,
#  'nh': 2.2,
#  'nimby': -0.8,
#  'nimjd': -0.7,
#  'nimq': -0.2,
#  'nimy': -1.4,
#  'nitl': -1.5,
#  'nme': -2.1,
#  'noyb': -0.7,
#  'np': 1.4,
#  'ntmu': 1.4,
#  'o-8': -0.5,
#  'o-:': -0.3,
#  'o-|': -1.1,
#  'o.o': -0.8,
#  'O.o': -0.6,
#  'o.O': -0.6,
#  'o:': -0.2,
#  'o:)': 1.5,
#  'o:-)': 2.0,
#  'o:-3': 2.2,
#  'o:3': 2.3,
#  'o:<': -0.3,
#  'o;^)': 1.6,
#  'ok': 1.2,
#  'o_o': -0.5,
#  'O_o': -0.5,
#  'o_O': -0.5,
#  'pita': -2.4,
#  'pls': 0.3,
#  'plz': 0.3,
#  'pmbi': 0.8,
#  'pmfji': 0.3,
#  'pmji': 0.7,
#  'po': -2.6,
#  'ptl': 2.6,
#  'pu': -1.1,
#  'qq': -2.2,
#  'qt': 1.8,
#  'r&r': 2.4,
#  'rofl': 2.7,
#  'roflmao': 2.5,
#  'rotfl': 2.6,
#  'rotflmao': 2.8,
#  'rotflmfao': 2.5,
#  'rotflol': 3.0,
#  'rotgl': 2.9,
#  'rotglmao': 1.8,
#  's:': -1.1,
#  'sapfu': -1.1,
#  'sete': 2.8,
#  'sfete': 2.7,
#  'sgtm': 2.4,
#  'slap': 0.6,
#  'slaw': 2.1,
#  'smh': -1.3,
#  'snafu': -2.5,
#  'sob': -1.0,
#  'swak': 2.3,
#  'tgif': 2.3,
#  'thks': 1.4,
#  'thx': 1.5,
#  'tia': 2.3,
#  'tmi': -0.3,
#  'tnx': 1.1,
#  'true': 1.8,
#  'tx': 1.5,
#  'txs': 1.1,
#  'ty': 1.6,
#  'tyvm': 2.5,
#  'urw': 1.9,
#  'vbg': 2.1,
#  'vbs': 3.1,
#  'vip': 2.3,
#  'vwd': 2.6,
#  'vwp': 2.1,
#  'wag': -0.2,
#  'wd': 2.7,
#  'wilco': 0.9,
#  'wp': 1.0,
#  'wtf': -2.8,
#  'wtg': 2.1,
#  'wth': -2.4,
#  'x-d': 2.6,
#  'x-p': 1.7,
#  'xd': 2.8,
#  'xlnt': 3.0,
#  'xoxo': 3.0,
#  'xoxozzz': 2.3,
#  'xp': 1.6,
#  'xqzt': 1.6,
#  'xtc': 0.8,
#  'yolo': 1.1,
#  'yoyo': 0.4,
#  'yvw': 1.6,
#  'yw': 1.8,
#  'ywia': 2.5,
#  'zzz': -1.2,
#  '[-;': 0.5,
#  '[:': 1.3,
#  '[;': 1.0,
#  '[=': 1.7,
#  '\\-:': -1.0,
#  '\\:': -1.0,
#  '\\:<': -1.7,
#  '\\=': -1.1,
#  '\\^:': -1.3,
#  '\\o/': 2.2,
#  '\\o:': -1.2,
#  ']-:': -2.1,
#  ']:': -1.6,
#  ']:<': -2.5,
#  '^<_<': 1.4,
#  '^urs': -2.8,
#  'abandon': -1.9,
#  'abandoned': -2.0,
#  'abandoner': -1.9,
#  'abandoners': -1.9,
#  'abandoning': -1.6,
#  'abandonment': -2.4,
#  'abandonments': -1.7,
#  'abandons': -1.3,
#  'abducted': -2.3,
#  'abduction': -2.8,
#  'abductions': -2.0,
#  'abhor': -2.0,
#  'abhorred': -2.4,
#  'abhorrent': -3.1,
#  'abhors': -2.9,
#  'abilities': 1.0,
#  'ability': 1.3,
#  'aboard': 0.1,
#  'absentee': -1.1,
#  'absentees': -0.8,
#  'absolve': 1.2,
#  'absolved': 1.5,
#  'absolves': 1.3,
#  'absolving': 1.6,
#  'abuse': -3.2,
#  'abused': -2.3,
#  'abuser': -2.6,
#  'abusers': -2.6,
#  'abuses': -2.6,
#  'abusing': -2.0,
#  'abusive': -3.2,
#  'abusively': -2.8,
#  'abusiveness': -2.5,
#  'abusivenesses': -3.0,
#  'accept': 1.6,
#  'acceptabilities': 1.6,
#  'acceptability': 1.1,
#  'acceptable': 1.3,
#  'acceptableness': 1.3,
#  'acceptably': 1.5,
#  'acceptance': 2.0,
#  'acceptances': 1.7,
#  'acceptant': 1.6,
#  'acceptation': 1.3,
#  'acceptations': 0.9,
#  'accepted': 1.1,
#  'accepting': 1.6,
#  'accepts': 1.3,
#  'accident': -2.1,
#  'accidental': -0.3,
#  'accidentally': -1.4,
#  'accidents': -1.3,
#  'accomplish': 1.8,
#  'accomplished': 1.9,
#  'accomplishes': 1.7,
#  'accusation': -1.0,
#  'accusations': -1.3,
#  'accuse': -0.8,
#  'accused': -1.2,
#  'accuses': -1.4,
#  'accusing': -0.7,
#  'ache': -1.6,
#  'ached': -1.6,
#  'aches': -1.0,
#  'achievable': 1.3,
#  'aching': -2.2,
#  'acquit': 0.8,
#  'acquits': 0.1,
#  'acquitted': 1.0,
#  'acquitting': 1.3,
#  'acrimonious': -1.7,
#  'active': 1.7,
#  'actively': 1.3,
#  'activeness': 0.6,
#  'activenesses': 0.8,
#  'actives': 1.1,
#  'adequate': 0.9,
#  'admirability': 2.4,
#  'admirable': 2.6,
#  'admirableness': 2.2,
#  'admirably': 2.5,
#  'admiral': 1.3,
#  'admirals': 1.5,
#  'admiralties': 1.6,
#  'admiralty': 1.2,
#  'admiration': 2.5,
#  'admirations': 1.6,
#  'admire': 2.1,
#  'admired': 2.3,
#  'admirer': 1.8,
#  'admirers': 1.7,
#  'admires': 1.5,
#  'admiring': 1.6,
#  'admiringly': 2.3,
#  'admit': 0.8,
#  'admits': 1.2,
#  'admitted': 0.4,
#  'admonished': -1.9,
#  'adopt': 0.7,
#  'adopts': 0.7,
#  'adorability': 2.2,
#  'adorable': 2.2,
#  'adorableness': 2.5,
#  'adorably': 2.1,
#  'adoration': 2.9,
#  'adorations': 2.2,
#  'adore': 2.6,
#  'adored': 1.8,
#  'adorer': 1.7,
#  'adorers': 2.1,
#  'adores': 1.6,
#  'adoring': 2.6,
#  'adoringly': 2.4,
#  'adorn': 0.9,
#  'adorned': 0.8,
#  'adorner': 1.3,
#  'adorners': 0.9,
#  'adorning': 1.0,
#  'adornment': 1.3,
#  'adornments': 0.8,
#  'adorns': 0.5,
#  'advanced': 1.0,
#  'advantage': 1.0,
#  'advantaged': 1.4,
#  'advantageous': 1.5,
#  'advantageously': 1.9,
#  'advantageousness': 1.6,
#  'advantages': 1.5,
#  'advantaging': 1.6,
#  'adventure': 1.3,
#  'adventured': 1.3,
#  'adventurer': 1.2,
#  'adventurers': 0.9,
#  'adventures': 1.4,
#  'adventuresome': 1.7,
#  'adventuresomeness': 1.3,
#  'adventuress': 0.8,
#  'adventuresses': 1.4,
#  'adventuring': 2.3,
#  'adventurism': 1.5,
#  'adventurist': 1.4,
#  'adventuristic': 1.7,
#  'adventurists': 1.2,
#  'adventurous': 1.4,
#  'adventurously': 1.3,
#  'adventurousness': 1.8,
#  'adversarial': -1.5,
#  'adversaries': -1.0,
#  'adversary': -0.8,
#  'adversative': -1.2,
#  'adversatively': -0.1,
#  'adversatives': -1.0,
#  'adverse': -1.5,
#  'adversely': -0.8,
#  'adverseness': -0.6,
#  'adversities': -1.5,
#  'adversity': -1.8,
#  'affected': -0.6,
#  'affection': 2.4,
#  'affectional': 1.9,
#  'affectionally': 1.5,
#  'affectionate': 1.9,
#  'affectionately': 2.2,
#  'affectioned': 1.8,
#  'affectionless': -2.0,
#  'affections': 1.5,
#  'afflicted': -1.5,
#  'affronted': 0.2,
#  'aggravate': -2.5,
#  'aggravated': -1.9,
#  'aggravates': -1.9,
#  'aggravating': -1.2,
#  'aggress': -1.3,
#  'aggressed': -1.4,
#  'aggresses': -0.5,
#  'aggressing': -0.6,
#  'aggression': -1.2,
#  'aggressions': -1.3,
#  'aggressive': -0.6,
#  'aggressively': -1.3,
#  'aggressiveness': -1.8,
#  'aggressivities': -1.4,
#  'aggressivity': -0.6,
#  'aggressor': -0.8,
#  'aggressors': -0.9,
#  'aghast': -1.9,
#  'agitate': -1.7,
#  'agitated': -2.0,
#  'agitatedly': -1.6,
#  'agitates': -1.4,
#  'agitating': -1.8,
#  'agitation': -1.0,
#  'agitational': -1.2,
#  'agitations': -1.3,
#  'agitative': -1.3,
#  'agitato': -0.1,
#  'agitator': -1.4,
#  'agitators': -2.1,
#  'agog': 1.9,
#  'agonise': -2.1,
#  'agonised': -2.3,
#  'agonises': -2.4,
#  'agonising': -1.5,
#  'agonize': -2.3,
#  'agonized': -2.2,
#  'agonizes': -2.3,
#  'agonizing': -2.7,
#  'agonizingly': -2.3,
#  'agony': -1.8,
#  'agree': 1.5,
#  'agreeability': 1.9,
#  'agreeable': 1.8,
#  'agreeableness': 1.8,
#  'agreeablenesses': 1.3,
#  'agreeably': 1.6,
#  'agreed': 1.1,
#  'agreeing': 1.4,
#  'agreement': 2.2,
#  'agreements': 1.1,
#  'agrees': 0.8,
#  'alarm': -1.4,
#  'alarmed': -1.4,
#  'alarming': -0.5,
#  'alarmingly': -2.6,
#  'alarmism': -0.3,
#  'alarmists': -1.1,
#  'alarms': -1.1,
#  'alas': -1.1,
#  'alert': 1.2,
#  'alienation': -1.1,
#  'alive': 1.6,
#  'allergic': -1.2,
#  'allow': 0.9,
#  'alone': -1.0,
#  'alright': 1.0,
#  'amaze': 2.5,
#  'amazed': 2.2,
#  'amazedly': 2.1,
#  'amazement': 2.5,
#  'amazements': 2.2,
#  'amazes': 2.2,
#  'amazing': 2.8,
#  'amazon': 0.7,
#  'amazonite': 0.2,
#  'amazons': -0.1,
#  'amazonstone': 1.0,
#  'amazonstones': 0.2,
#  'ambitious': 2.1,
#  'ambivalent': 0.5,
#  'amor': 3.0,
#  'amoral': -1.6,
#  'amoralism': -0.7,
#  'amoralisms': -0.7,
#  'amoralities': -1.2,
#  'amorality': -1.5,
#  'amorally': -1.0,
#  'amoretti': 0.2,
#  'amoretto': 0.6,
#  'amorettos': 0.3,
#  'amorino': 1.2,
#  'amorist': 1.6,
#  'amoristic': 1.0,
#  'amorists': 0.1,
#  'amoroso': 2.3,
#  'amorous': 1.8,
#  'amorously': 2.3,
#  'amorousness': 2.0,
#  'amorphous': -0.2,
#  'amorphously': 0.1,
#  'amorphousness': 0.3,
#  'amort': -2.1,
#  'amortise': 0.5,
#  'amortised': -0.2,
#  'amortises': 0.1,
#  'amortizable': 0.5,
#  'amortization': 0.6,
#  'amortizations': 0.2,
#  'amortize': -0.1,
#  'amortized': 0.8,
#  'amortizes': 0.6,
#  'amortizing': 0.8,
#  'amusable': 0.7,
#  'amuse': 1.7,
#  'amused': 1.8,
#  'amusedly': 2.2,
#  'amusement': 1.5,
#  'amusements': 1.5,
#  'amuser': 1.1,
#  'amusers': 1.3,
#  'amuses': 1.7,
#  'amusia': 0.3,
#  'amusias': -0.4,
#  'amusing': 1.6,
#  'amusingly': 0.8,
#  'amusingness': 1.8,
#  'amusive': 1.7,
#  'anger': -2.7,
#  'angered': -2.3,
#  'angering': -2.2,
#  'angerly': -1.9,
#  'angers': -2.3,
#  'angrier': -2.3,
#  'angriest': -3.1,
#  'angrily': -1.8,
#  'angriness': -1.7,
#  'angry': -2.3,
#  'anguish': -2.9,
#  'anguished': -1.8,
#  'anguishes': -2.1,
#  'anguishing': -2.7,
#  'animosity': -1.9,
#  'annoy': -1.9,
#  'annoyance': -1.3,
#  'annoyances': -1.8,
#  'annoyed': -1.6,
#  'annoyer': -2.2,
#  'annoyers': -1.5,
#  'annoying': -1.7,
#  'annoys': -1.8,
#  'antagonism': -1.9,
#  'antagonisms': -1.2,
#  'antagonist': -1.9,
#  'antagonistic': -1.7,
#  'antagonistically': -2.2,
#  'antagonists': -1.7,
#  'antagonize': -2.0,
#  'antagonized': -1.4,
#  'antagonizes': -0.5,
#  'antagonizing': -2.7,
#  'anti': -1.3,
#  'anticipation': 0.4,
#  'anxieties': -0.6,
#  'anxiety': -0.7,
#  'anxious': -1.0,
#  'anxiously': -0.9,
#  'anxiousness': -1.0,
#  'aok': 2.0,
#  'apathetic': -1.2,
#  'apathetically': -0.4,
#  'apathies': -0.6,
#  'apathy': -1.2,
#  'apeshit': -0.9,
#  'apocalyptic': -3.4,
#  'apologise': 1.6,
#  'apologised': 0.4,
#  'apologises': 0.8,
#  'apologising': 0.2,
#  'apologize': 0.4,
#  'apologized': 1.3,
#  'apologizes': 1.5,
#  'apologizing': -0.3,
#  'apology': 0.2,
#  'appall': -2.4,
#  'appalled': -2.0,
#  'appalling': -1.5,
#  'appallingly': -2.0,
#  'appalls': -1.9,
#  'appease': 1.1,
#  'appeased': 0.9,
#  'appeases': 0.9,
#  'appeasing': 1.0,
#  'applaud': 2.0,
#  'applauded': 1.5,
#  'applauding': 2.1,
#  'applauds': 1.4,
#  'applause': 1.8,
#  'appreciate': 1.7,
#  'appreciated': 2.3,
#  'appreciates': 2.3,
#  'appreciating': 1.9,
#  'appreciation': 2.3,
#  'appreciations': 1.7,
#  'appreciative': 2.6,
#  'appreciatively': 1.8,
#  'appreciativeness': 1.6,
#  'appreciator': 2.6,
#  'appreciators': 1.5,
#  'appreciatory': 1.7,
#  'apprehensible': 1.1,
#  'apprehensibly': -0.2,
#  'apprehension': -2.1,
#  'apprehensions': -0.9,
#  'apprehensively': -0.3,
#  'apprehensiveness': -0.7,
#  'approval': 2.1,
#  'approved': 1.8,
#  'approves': 1.7,
#  'ardent': 2.1,
#  'arguable': -1.0,
#  'arguably': -1.0,
#  'argue': -1.4,
#  'argued': -1.5,
#  'arguer': -1.6,
#  'arguers': -1.4,
#  'argues': -1.6,
#  'arguing': -2.0,
#  'argument': -1.5,
#  'argumentative': -1.5,
#  'argumentatively': -1.8,
#  'argumentive': -1.5,
#  'arguments': -1.7,
#  'arrest': -1.4,
#  'arrested': -2.1,
#  'arrests': -1.9,
#  'arrogance': -2.4,
#  'arrogances': -1.9,
#  'arrogant': -2.2,
#  'arrogantly': -1.8,
#  'ashamed': -2.1,
#  'ashamedly': -1.7,
#  'ass': -2.5,
#  'assassination': -2.9,
#  'assassinations': -2.7,
#  'assault': -2.8,
#  'assaulted': -2.4,
#  'assaulting': -2.3,
#  'assaultive': -2.8,
#  'assaults': -2.5,
#  'asset': 1.5,
#  'assets': 0.7,
#  'assfucking': -2.5,
#  'assholes': -2.8,
#  'assurance': 1.4,
#  'assurances': 1.4,
#  'assure': 1.4,
#  'assured': 1.5,
#  'assuredly': 1.6,
#  'assuredness': 1.4,
#  'assurer': 0.9,
#  'assurers': 1.1,
#  'assures': 1.3,
#  'assurgent': 1.3,
#  'assuring': 1.6,
#  'assuror': 0.5,
#  'assurors': 0.7,
#  'astonished': 1.6,
#  'astound': 1.7,
#  'astounded': 1.8,
#  'astounding': 1.8,
#  'astoundingly': 2.1,
#  'astounds': 2.1,
#  'attachment': 1.2,
#  'attachments': 1.1,
#  'attack': -2.1,
#  'attacked': -2.0,
#  'attacker': -2.7,
#  'attackers': -2.7,
#  'attacking': -2.0,
#  'attacks': -1.9,
#  'attract': 1.5,
#  'attractancy': 0.9,
#  'attractant': 1.3,
#  'attractants': 1.4,
#  'attracted': 1.8,
#  'attracting': 2.1,
#  'attraction': 2.0,
#  'attractions': 1.8,
#  'attractive': 1.9,
#  'attractively': 2.2,
#  'attractiveness': 1.8,
#  'attractivenesses': 2.1,
#  'attractor': 1.2,
#  'attractors': 1.2,
#  'attracts': 1.7,
#  'audacious': 0.9,
#  'authority': 0.3,
#  'aversion': -1.9,
#  'aversions': -1.1,
#  'aversive': -1.6,
#  'aversively': -0.8,
#  'avert': -0.7,
#  'averted': -0.3,
#  'averts': -0.4,
#  'avid': 1.2,
#  'avoid': -1.2,
#  'avoidance': -1.7,
#  'avoidances': -1.1,
#  'avoided': -1.4,
#  'avoider': -1.8,
#  'avoiders': -1.4,
#  'avoiding': -1.4,
#  'avoids': -0.7,
#  'await': 0.4,
#  'awaited': -0.1,
#  'awaits': 0.3,
#  'award': 2.5,
#  'awardable': 2.4,
#  'awarded': 1.7,
#  'awardee': 1.8,
#  'awardees': 1.2,
#  'awarder': 0.9,
#  'awarders': 1.3,
#  'awarding': 1.9,
#  'awards': 2.0,
#  'awesome': 3.1,
#  'awful': -2.0,
#  'awkward': -0.6,
#  'awkwardly': -1.3,
#  'awkwardness': -0.7,
#  'axe': -0.4,
#  'axed': -1.3,
#  'backed': 0.1,
#  'backing': 0.1,
#  'backs': -0.2,
#  'bad': -2.5,
#  'badass': -0.6,
#  'badly': -2.1,
#  'bailout': -0.4,
#  'bamboozle': -1.5,
#  'bamboozled': -1.5,
#  'bamboozles': -1.5,
#  'ban': -2.6,
#  'banish': -1.9,
#  'bankrupt': -2.6,
#  'bankster': -2.1,
#  'banned': -2.0,
#  'bargain': 0.8,
#  'barrier': -0.5,
#  'bashful': -0.1,
#  'bashfully': 0.2,
#  'bashfulness': -0.8,
#  'bastard': -2.5,
#  'bastardies': -1.8,
#  'bastardise': -2.1,
#  'bastardised': -2.3,
#  'bastardises': -2.3,
#  'bastardising': -2.6,
#  'bastardization': -2.4,
#  'bastardizations': -2.1,
#  'bastardize': -2.4,
#  'bastardized': -2.0,
#  'bastardizes': -1.8,
#  'bastardizing': -2.3,
#  'bastardly': -2.7,
#  'bastards': -3.0,
#  'bastardy': -2.7,
#  'battle': -1.6,
#  'battled': -1.2,
#  'battlefield': -1.6,
#  'battlefields': -0.9,
#  'battlefront': -1.2,
#  'battlefronts': -0.8,
#  'battleground': -1.7,
#  'battlegrounds': -0.6,
#  'battlement': -0.4,
#  'battlements': -0.4,
#  'battler': -0.8,
#  'battlers': -0.2,
#  'battles': -1.6,
#  'battleship': -0.1,
#  'battleships': -0.5,
#  'battlewagon': -0.3,
#  'battlewagons': -0.5,
#  'battling': -1.1,
#  'beaten': -1.8,
#  'beatific': 1.8,
#  'beating': -2.0,
#  'beaut': 1.6,
#  'beauteous': 2.5,
#  'beauteously': 2.6,
#  'beauteousness': 2.7,
#  'beautician': 1.2,
#  'beauticians': 0.4,
#  ...}

# %%
search_results = pd.read_csv("output data/preprocessed_aldo_AI_search_results.csv")

# %%
sia = SentimentIntensityAnalyzer()

def get_sentiment(text):
    if not text.strip():
        return 0  # Neutral for empty text
    blob_score = TextBlob(text).sentiment.polarity
    vader_score = sia.polarity_scores(text)['compound']
    
    # Average
    average = (blob_score + vader_score) / 2
    
    # Return individual 
    return blob_score, vader_score, average

# Add each score to a separate column
search_results['blob_score'], search_results['vader_score'], search_results['sentiment_score'] = \
    zip(*search_results['lemmatized_stemmed_text'].apply(get_sentiment))

search_results
# Out:
#                                                title                 date  \
# 0  ALDO Group Invests in Predictive AI for Demand...  Unrecognized format
# 1  Inside ALDO's in-house generative AI and machi...           08-07-2024
# 2                            ALDO Group | Contentful       Date not found
# 3  Aldo's AI Investments Include Celebrity Picks ...           29-07-2024
# 4  How Aldo puts its best foot forward with a uni...  Unrecognized format
# 5  ALDO Group's AI Revolution | Fatih Nayebi, Ph....       Date not found
# 6  DataSphere Lab & ALDO Group Partnership: Shapi...       Date not found
# 7  SCALE AI is announcing investments of more tha...           28-09-2023
# 8  Retail Gen AI Hackathon | Bensadoun School of ...  Unrecognized format
#
#                                                 link         displayLink  \
# 0  https://www.asug.com/insights/aldo-group-inves...        www.asug.com
# 1  https://digiday.com/marketing/inside-aldos-in-...         digiday.com
# 2  https://www.contentful.com/case-studies/aldo-g...  www.contentful.com
# 3  https://consumergoods.com/aldos-ai-investments...   consumergoods.com
# 4  https://emarsys.com/why-emarsys/success-storie...         emarsys.com
# 5  https://www.linkedin.com/posts/thefatih_2023-i...    www.linkedin.com
# 6  https://www.mcgill.ca/bensadoun-school/data-sp...       www.mcgill.ca
# 7  https://www.scaleai.ca/scale-ai-is-announcing-...      www.scaleai.ca
# 8  https://www.mcgill.ca/bensadoun-school/feature...       www.mcgill.ca
#
#                                              snippet  \
# 0  Aug 16, 2024 ... ALDO Group is helping to deve...
# 1  Jul 8, 2024 ... Amidst the artificial intellig...
# 2  Content plays a key role in the ALDO Group's e...
# 3  Jul 29, 2024 ... As part of its artificial int...
# 4  The Business. With its signature brands ALDO, ...
# 5  Jul 12, 2024 ... A comprehensive document show...
# 6  The DataSphere Lab (DSL) at McGill University'...
# 7  Sep 28, 2023 ... The ALDO Group, a leading Can...
# 8  This first edition of the Retail Gen AI Hackat...
#
#                                                 body  \
# 0  AI for Demand Forecasting Author ASUG Staff Pu...
# 1  Subscribe | Login Reader Digiday+ Member Subsc...
# 2  LivestreamJoin us March 31 as we unveil the fu...
# 3  Subscribe Subscribe Subscribe Subscribe News L...
# 4  foot forward with a unified e-commerce system ...
# 5  LinkedIn and 3rd parties use essential and non...
# 6  Partnership Retail Gen AI Hackathon Our Team C...
# 7  of more than $20 million in 5 AI projects for ...
# 8  Fall 2024 September 26 - October 4, 2024 The s...
#
#                                         cleaned_text  \
# 0  ai demand forecasting author asug staff publis...
# 1  subscribe login reader digiday member subscrib...
# 2  livestreamjoin us march unveil future digital ...
# 3  subscribe subscribe subscribe subscribe news l...
# 4  foot forward unified e commerce system puts be...
# 5  linkedin 3rd parties use essential non essenti...
# 6  partnership retail ai hackathon team contact u...
# 7  million ai projects intelligent supply chains ...
# 8  fall september october second edition bensadou...
#
#                              lemmatized_stemmed_text  blob_score  vader_score  \
# 0  ai demand forecast author asug staff publish r...    0.076984       0.9719
# 1  subscrib login reader digiday member subscrib ...    0.087302       0.9648
# 2  livestreamjoin u march unveil futur digit expe...    0.310000       0.9694
# 3  subscrib subscrib subscrib subscrib news lates...    0.106463       0.9856
# 4  foot forward unifi e commerc system put best f...    0.175685       0.9801
# 5  linkedin 3rd parti use essenti non essenti coo...    0.000000       0.6908
# 6  partnership retail ai hackathon team contact u...    0.100000       0.6249
# 7  million ai project intellig suppli chain back ...   -0.067803       0.9794
# 8  fall septemb octob second edit bensadoun schoo...    0.119318       0.9855
#
#    sentiment_score
# 0         0.524442
# 1         0.526051
# 2         0.639700
# 3         0.546031
# 4         0.577893
# 5         0.345400
# 6         0.362450
# 7         0.455798
# 8         0.552409

# %%
# Save the results
search_results.to_csv("output data/sentiment_aldo_AI_search_results.csv", index=False)

# %% [markdown]
# ## Improvements for the Next Round:
# - Get article dates from delimiter "..." in snippet
# - Use more sentiment analyzers like BERT and customized BERTs
# - Explore topic analytics, text analytics from each article to add understanding
